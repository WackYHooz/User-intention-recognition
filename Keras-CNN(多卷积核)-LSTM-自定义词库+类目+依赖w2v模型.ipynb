# %%
# 两次分类，现将用户输入按照意愿进行分类（愿意还款，意图模糊，延期还款，其它），再根据不同意愿进行进一步分类
# 理论上，意愿分类的准确率会很高，限定意愿后的进一步分类准确率也会有所提高
# 仅使用多卷积核CNN进行特征的综合提取
# 对于池化尺寸的大小未定，需加大样本数量进行对比
import keras
import xlrd, xlwt
from xlutils import copy
import os
import random
import gensim
from gensim.models import Word2Vec
from keras.models import Model
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras import regularizers
from keras.layers.embeddings import Embedding
import jieba
import numpy as np
import time
from keras.utils.np_utils import to_categorical
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D, Dropout, LSTM, SpatialDropout1D, LeakyReLU, Input, concatenate
import sklearn
from sklearn.model_selection import train_test_split
from keras.models import load_model
import datetime
# Out:
# Using TensorFlow backend.

# %%
# 对于两次分类问题，需要对样本打两个标签（意愿标签和具体标签）
# 标签提取
def label_preprocessing(label, num_classes):
#     0: 愿意还款; 1: 意图模糊; 2: 延期还款; 3: 其他（全局）; 
    label = np.array(label)
    categorical_labels = to_categorical(label, num_classes=num_classes)
    return categorical_labels

# 数据集预处理(jieba分词，生成词袋，计算字典大小)
def data_preprocessing(data):
    total_words = []
    tokenized = []
    
    for pattern in data:
        sts = ""
        for word in pattern:
            if word not in pre_stopwords:
                sts += word
        t = jieba.lcut(sts)
        t_s = []
        for word in t:
            if word not in pos_stopwords:
                t_s.append(word)
        total_words.extend(t_s)
        tokenized.append(t_s)

    return tokenized

# 在预测时，寻找包含新词的句子
def find_new_wd_of_sts(data, new_wd_of_sts_idx):
    fobj = open('包含新词的句子.txt','a')
    for i in new_wd_of_sts_idx:
        fobj.write('\n'+data[i])
    print('save the new word of setense')
    fobj.close()

# 短句补零，使训练集文本长度相同
def padding_sts(identify,max_len=None):
#     若不预设最大长度，则计算传入样本中的最大长度
    if max_len is None:
        max_len = 0
        for sts in identify:
            if len(sts)>max_len:
                max_len = len(sts)
    padded_id = list(map(lambda l:l + [0]*(max_len - len(l)), identify))
    padded_id = np.array(padded_id)
    return padded_id, max_len

# 数据集切分
def split_data_set(data, label, ratio, seed=None, detal=False):
    data_1, data_2, label_1, label_2 = train_test_split(data, label, test_size=ratio, random_state=seed)
# data：待划分的样本特征集
# label：待划分的样本标签
# ratio：划分比例。如果是浮点数，在0-1之间，表示样本占比；如果是整数，表示样本数量
# seed：是随机数的种子。
# 随机数种子：填0或不填，每次生成的数据集都会不一样。
# detal：显示分割后的详情。默认False
    if detal == True:
        print("data_1_len: ", len(data_1),"label_1_len: ", len(label_1),\
              "\ndata_2_len: ", len(data_2),"lebal_2_len: ", len(label_2))
    return data_1, data_2, label_1, label_2

# 预训练词向量模型
def build_word2vec(data, w2v_dims, w2v_model=None, update=True):
    date = time.strftime("%Y%m%d")
    tokenized = []
    max_len = 0
    
    for pattern in data:
        sts = ""
#         去前停用词
        for word in pattern:
            if word not in pre_stopwords:
                sts += word
        t = jieba.lcut(sts)
        t_s = []
#         去后停用词
        for word in t:
            if word not in pos_stopwords:
                t_s.append(word)
        tokenized.append(t_s)
#         计算分词后的最长长度
        if len(t_s) > max_len:
            max_len = len(t_s)
        
        
# 若没有传入词向量模型，生成新的模型
    if w2v_model is None:
        print('正在生成新的词向量模型...')
        w2v_model = Word2Vec(tokenized,sg=1,size=w2v_dims,window=5,min_count=1,negative=1,sample=0.001,hs=1)
        w2v_model.train(tokenized, total_examples=len(tokenized), epochs=5)
# 若传入了词向量模型，则更新模型
    elif update is True:
        print('正在更新词向量...')
        w2v_model = update_w2v(w2v_model, tokenized)
    return w2v_model, max_len

# 更新词向量模型
def update_w2v(w2v_model, tokenized):
#     生成原词向量的词表
    vocab_list = []
    for w, _ in w2v_model.wv.vocab.items():
        vocab_list.append(w)
#     寻找词向量模型中没有的新词
    new_sts = []
    new_wd = []
    for sts in tokenized:
        for wd in sts:
            if wd not in vocab_list:
                new_wd.append(wd)
                new_sts.append(sts)
                break
    if new_sts != []:
        print('发现新词：', new_wd, '\n已对词向量模型进行更新！')
        w2v_model.build_vocab(new_sts, update=True)
#         w2v_model.train(new_sts,total_examples=w2v_model.corpus_count,epochs=1)
    else:
        print('未发现新词')
    return w2v_model

# 对数据集中的每个词，按照词向量索引进行编码
def wd_encode(wd2idx, tokenized):
    identify = []
    for sts in tokenized:
        id_sts = []
        for wd in sts:
            id_sts.append(wd2idx[wd])
        identify.append(id_sts)
    return identify

# 构建词向量的单词索引和embedding层矩阵
def build_wd2idx_embedMatrix(w2vModel):
    word2idx = {"_stopWord": 0}  # 这里加了一行是用来过滤停用词的。
    vocab_list = [(w, w2vModel.wv[w]) for w, v in w2vModel.wv.vocab.items()]
    embedMatrix = np.zeros((len(w2vModel.wv.vocab.items()) + 1, w2vModel.vector_size))

    for i in range(0, len(vocab_list)):
        word = vocab_list[i][0]
        word2idx[word] = i + 1
        embedMatrix[i + 1] = vocab_list[i][1]
    return word2idx, embedMatrix

# 将深度学习过程中训练的词向量矩阵更新到词向量模型中
def embed2w2v(w2vModel, embedMatrix):
    print('正在根据学习过程中训练的词向量矩阵对词向量模型进行更新...')
    i = 0
    for w,_ in w2vModel.wv.vocab.items():
        w2vModel.wv[w] = embedMatrix[i]
        i += 1
    print('词向量模型更新完成')
    return w2vModel

# 显示每次运行片段的时间
def ThisTime():
    print('This time is: ', time.strftime("%Y-%m-%d %H:%M:%S"))

# %%
# 训练集和对应标签预处理
date = time.strftime("%Y%m%d")
readbook = xlrd.open_workbook('催收-用户输入-样本及标签.xlsx')
sheet1 = readbook.sheet_by_name('data & labels')
sheet2 = readbook.sheet_by_name('pre_stopwords')
sheet3 = readbook.sheet_by_name('pos_stopwords')

data_set = []
pre_label = []
pos_label = []
pre_stopwords = []
pos_stopwords = []
w2v_dims = 200

for i in range(sheet1.nrows-1):
    data_set.append(sheet1.cell(i+1,0).value)
    pre_label.append(sheet1.cell(i+1,1).value)
#     pos_label.append(sheet1.cell(i+1,2).value)

for i in range(sheet2.nrows):
    pre_stopwords.append(sheet2.cell(i,0).value)
    
for i in range(sheet3.nrows):
    pos_stopwords.append(sheet3.cell(i,0).value)

# 加载自定义词典
jieba.load_userdict("催收文本-newdic.txt")

# 构建数据集词库
total_set = xlrd.open_workbook('语音转文本_全业务数据集.xlsx')
total_set_sheet1 = total_set.sheet_by_name('Sheet1')
total_data = []
for i in range(total_set_sheet1.nrows-1):
    total_data.append(total_set_sheet1.cell(i+1,0).value)

# 载入原有的词向量模型
# w2v_model = Word2Vec.load(date+'_w2v_model')
# w2v_model = Word2Vec.load(date+'_w2v_model_pos_embed')
# w2v_model = Word2Vec.load('20190528_w2v_model')

# 默认构建新的词向量模型。若要在原有模型基础上继续训练，build_word2vec函数需传入词向量模型
# 若使用原有词向量模型，考虑到可能会出现新词汇，在使用前需进行模型更新
w2v_model, max_len = build_word2vec(total_data, w2v_dims, update=True)
w2v_model.save(date+'_w2v_model')# 保存模型
print('词向量模型保存成功：%s_w2v_model' %date)

# 将词向量模型加载为数组
wd2idx, embedMatrix = build_wd2idx_embedMatrix(w2v_model)

num_pre_classes = 20
num_pos_classes = 5
# num_pos_classes_1 = 2
# num_pos_classes_2 = 3
# num_pos_classes_3 = 2
# num_pos_classes_4 = 5
tokenized = data_preprocessing(data_set)
identify = wd_encode(wd2idx, tokenized)
padded_data,_ = padding_sts(identify, max_len=max_len)
# print(pre_label)
pre_label = label_preprocessing(pre_label, num_pre_classes)
# pos_label = label_preprocessing(pos_label, num_pos_classes)

dictionary = []
for i in range(len(tokenized)):
    dictionary.append({'sentence':data_set[i-1], 'tokenized':tokenized[i-1],\
                       'id':padded_data[i-1], 'pre_label':pre_label[i-1]})
# print(dictionary)
rand = random.randint(1,10000)

# 对数据集进行切分，生成训练集和验证集
train_data, validate_data, train_pre_label, validate_pre_label = \
split_data_set(padded_data, pre_label, 0.1, seed=rand, detal=True)
# train_data, test_data, train_pos_label, test_pos_label = \
# split_data_set(padded_data, pos_label, 0.1, seed=rand, detal=True)

# 对训练集进行切分，生成训练集和测试集
train_data, test_data, train_pre_label, test_pre_label = \
split_data_set(train_data, train_pre_label, 0.222, seed=rand, detal=True)
# train_data_tmp, validate_data, train_pos_label, validate_pos_label = \
# split_data_set(train_data, train_pos_label, 0.222, seed=rand, detal=True)
# train_data = train_data_tmp
# Out:
# 正在生成新的词向量模型...
# 词向量模型保存成功：20190606_w2v_model
# data_1_len:  24939 label_1_len:  24939
# data_2_len:  2771 lebal_2_len:  2771
# data_1_len:  19402 label_1_len:  19402
# data_2_len:  5537 lebal_2_len:  5537

# %%
# 设计网络模型：LSTM+六个卷积核(各10个特征)+LeakyReLU激活函数
# Input
comment_seq = Input(shape=[max_len], name='x_seq')
# Embedding
emb_comment = Embedding(len(embedMatrix), w2v_dims, weights=[embedMatrix], input_length=max_len, trainable=False)(comment_seq)
# LSTM
LSTM_1 = LSTM(units=32, dropout=0.2, recurrent_dropout=0.1, return_sequences=True)(emb_comment)
# LSTM_1 = LSTM(200, dropout=0.2, recurrent_dropout=0.2, return_sequences=True)(emb_comment)
# model.add(LSTM(200, return_sequences=True))
# LSTM_2 = LSTM(200, return_sequences=False)(LSTM_1)
# conv
convs = []
kernel_size = [1,2,3,4,5,max_len]
for ksz in kernel_size:
    l_conv = Conv1D(filters=10, kernel_size=ksz, strides=1, padding='valid',\
                   use_bias=True,kernel_initializer='glorot_uniform',\
                   bias_initializer='zeros',kernel_regularizer=regularizers.l2(0.0001))(LSTM_1)
    l_conv = LeakyReLU(alpha=0.01)(l_conv)
    l_pool = GlobalMaxPooling1D()(l_conv)
    convs.append(l_pool)
merge = concatenate(convs, axis=1)
dropout = Dropout(0.3)(merge)
# output = Dense(120)(merge)
# output = LeakyReLU(alpha=0.05)(output)
output = Dense(num_pre_classes,activation='softmax')(dropout)
model = Model([comment_seq], output)

# summarize the model
model.summary()
Adam = keras.optimizers.Adam(lr=0.01)
model.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['acc'])


ThisTime()

# Accuracy: 88.709677
# Loss: 0.558412
# This time is:  2019-05-08 14:35:49

# Accuracy: 81.012658
# Loss: 0.544165
# This time is:  2019-05-08 15:53:01

# Accuracy: 88.607595
# Loss: 0.307871
# This time is:  2019-05-08 16:20:03
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# x_seq (InputLayer)              (None, 42)           0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 42, 200)      2482000     x_seq[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 42, 32)       29824       embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 42, 10)       330         lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 41, 10)       650         lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 40, 10)       970         lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 39, 10)       1290        lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 38, 10)       1610        lstm_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 1, 10)        13450       lstm_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 42, 10)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 41, 10)       0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 40, 10)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 39, 10)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 38, 10)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 1, 10)        0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 10)           0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_8 (GlobalM (None, 10)           0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_9 (GlobalM (None, 10)           0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_10 (Global (None, 10)           0           leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_11 (Global (None, 10)           0           leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_12 (Global (None, 10)           0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 60)           0           global_max_pooling1d_7[0][0]
#                                                                  global_max_pooling1d_8[0][0]
#                                                                  global_max_pooling1d_9[0][0]
#                                                                  global_max_pooling1d_10[0][0]
#                                                                  global_max_pooling1d_11[0][0]
#                                                                  global_max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 60)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 20)           1220        dropout_2[0][0]
# ==================================================================================================
# Total params: 2,531,344
# Trainable params: 49,344
# Non-trainable params: 2,482,000
# __________________________________________________________________________________________________
# This time is:  2019-06-06 18:59:27

# %%
# 训练网络模型
# verbose:显示日志。verbose=0: 为不在标准输出流输出日志信息 verbose=1: 为输出进度条记录 verbose=2: 为每个epoch输出一行记录
start_time = time.time()
# for i in range(500):
# hist = model.fit(padded_data, categorical_labels,\
#                  epochs=100, verbose=1, validation_split=0.2,\
#                  steps_per_epoch=1, validation_steps=10, shuffle=True)
loss_tmp = 10
lr_pre = 0.01
lr = lr_pre
count = 1
threshold = 5

#     动态学习速率衰减
while lr >= lr_pre/64:
    hist = model.fit(train_data, train_pre_label, epochs=1, verbose=1)
#     每次只取随机一部分验证集进行验证，防止对验证集的过拟合
#     _, v_d, _, v_l = split_data_set(validate_data, validate_label,\
#                                     1, seed=None, detal=False)
#     loss, _ = model.evaluate(v_d, v_l, verbose=0)
    loss, _ = model.evaluate(validate_data, validate_pre_label, verbose=0)
    print(loss)

    if loss < loss_tmp:
        count = 1
        loss_tmp = loss
        model.save('Keras_cuishou_model')
    elif count >= threshold:
        model = load_model('Keras_cuishou_model')
        print("decay the learning rate")
        lr = lr/2
        Adam = keras.optimizers.Adam(lr=lr)
        model.compile(optimizer=Adam, loss='categorical_crossentropy', metrics=['acc'])
        count = 1
    else:
        count += 1

# new_embedMatirx = model.layers[1].get_weights()[0]# 获取embedding层的参数(词向量矩阵)
# w2v_model = embed2w2v(w2v_model, new_embedMatirx)# 对词向量模型进行更新

# w2v_model.save(date+'_w2v_model_pos_embed')# 保存模型
# print('词向量模型保存成功：%s_w2v_model_pos_embed' %date)
        
elapsed_time = time.time() - start_time
print ("processing time:", elapsed_time, "seconds")
# Out:
# Epoch 1/1
# 19402/19402 [==============================] - 48s 2ms/step - loss: 0.5130 - acc: 0.8569
# 0.3400517814493231
# Epoch 1/1
# 19402/19402 [==============================] - 35s 2ms/step - loss: 0.3314 - acc: 0.9128
# 0.3084949768867272
# Epoch 1/1
# 19402/19402 [==============================] - 38s 2ms/step - loss: 0.3005 - acc: 0.9236
# 0.29346667416729855
# Epoch 1/1
# 19402/19402 [==============================] - 37s 2ms/step - loss: 0.2853 - acc: 0.9297
# 0.31170352967540005
# Epoch 1/1
# 19402/19402 [==============================] - 38s 2ms/step - loss: 0.2744 - acc: 0.9346
# 0.2881868067242875
# Epoch 1/1
# 19402/19402 [==============================] - 40s 2ms/step - loss: 0.2601 - acc: 0.9369
# 0.3123054650448497
# Epoch 1/1
# 19402/19402 [==============================] - 35s 2ms/step - loss: 0.2535 - acc: 0.9392
# 0.3340319973365876
# Epoch 1/1
# 19402/19402 [==============================] - 39s 2ms/step - loss: 0.2521 - acc: 0.9406
# 0.3320388200802736
# Epoch 1/1
# 19402/19402 [==============================] - 31s 2ms/step - loss: 0.2489 - acc: 0.9421
# 0.3363660401878095
# Epoch 1/1
# 19402/19402 [==============================] - 31s 2ms/step - loss: 0.2449 - acc: 0.9431
# 0.32055108143249944
# decay the learning rate
# Epoch 1/1
# 19402/19402 [==============================] - 42s 2ms/step - loss: 0.2173 - acc: 0.9450
# 0.29165140813931106
# Epoch 1/1
# 19402/19402 [==============================] - 38s 2ms/step - loss: 0.2099 - acc: 0.9482
# 0.2638187049120095
# Epoch 1/1
# 19402/19402 [==============================] - 37s 2ms/step - loss: 0.1850 - acc: 0.9540
# 0.2821246832878054
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1822 - acc: 0.9564
# 0.2685039545043373
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1748 - acc: 0.9557
# 0.2823377594927165
# Epoch 1/1
# 19402/19402 [==============================] - 35s 2ms/step - loss: 0.1695 - acc: 0.9589
# 0.2920018430545157
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1610 - acc: 0.9604
# 0.2925400561543846
# decay the learning rate
# Epoch 1/1
# 19402/19402 [==============================] - 48s 2ms/step - loss: 0.1641 - acc: 0.9601
# 0.26127907093876496
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1527 - acc: 0.9613
# 0.2583389167147223
# Epoch 1/1
# 19402/19402 [==============================] - 38s 2ms/step - loss: 0.1455 - acc: 0.9641: 1s - loss:
# 0.2587756382907095
# Epoch 1/1
# 19402/19402 [==============================] - 39s 2ms/step - loss: 0.1404 - acc: 0.9641
# 0.26617774982522946
# Epoch 1/1
# 19402/19402 [==============================] - 39s 2ms/step - loss: 0.1379 - acc: 0.9668
# 0.26427355898024585
# Epoch 1/1
# 19402/19402 [==============================] - 36s 2ms/step - loss: 0.1303 - acc: 0.9671
# 0.2686422257292619
# Epoch 1/1
# 19402/19402 [==============================] - 40s 2ms/step - loss: 0.1289 - acc: 0.9676
# 0.269149413890935
# decay the learning rate
# Epoch 1/1
# 19402/19402 [==============================] - 44s 2ms/step - loss: 0.1388 - acc: 0.9659
# 0.25955233284386864
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1314 - acc: 0.9670
# 0.2642374156571949
# Epoch 1/1
# 19402/19402 [==============================] - 40s 2ms/step - loss: 0.1261 - acc: 0.9684
# 0.26251037295696666
# Epoch 1/1
# 19402/19402 [==============================] - 43s 2ms/step - loss: 0.1209 - acc: 0.9698
# 0.2617088542738274
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1155 - acc: 0.9714
# 0.2621652636447137
# decay the learning rate
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1355 - acc: 0.9667
# 0.25651270345805227
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1296 - acc: 0.9675
# 0.2563588044480785
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1258 - acc: 0.9687
# 0.2540519025213062
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1237 - acc: 0.9696
# 0.2533298111787904
# Epoch 1/1
# 19402/19402 [==============================] - 42s 2ms/step - loss: 0.1253 - acc: 0.9678
# 0.2527771238835871
# Epoch 1/1
# 19402/19402 [==============================] - 46s 2ms/step - loss: 0.1159 - acc: 0.9713
# 0.2569551907025361
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1155 - acc: 0.9702
# 0.2508931579528755
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1132 - acc: 0.9710
# 0.2542632974815988
# Epoch 1/1
# 19402/19402 [==============================] - 34s 2ms/step - loss: 0.1074 - acc: 0.9737: 4s -
# 0.2563361313768089
# Epoch 1/1
# 19402/19402 [==============================] - 41s 2ms/step - loss: 0.1107 - acc: 0.9715
# 0.2531684740103354
# Epoch 1/1
# 19402/19402 [==============================] - 43s 2ms/step - loss: 0.1044 - acc: 0.9725
# 0.2583026305642295
# Epoch 1/1
# 19402/19402 [==============================] - 42s 2ms/step - loss: 0.1026 - acc: 0.9744
# 0.26137182988745344
# decay the learning rate
# Epoch 1/1
# 19402/19402 [==============================] - 56s 3ms/step - loss: 0.1079 - acc: 0.9740: 1s - loss:
# 0.2535422728707841
# Epoch 1/1
# 19402/19402 [==============================] - 43s 2ms/step - loss: 0.1085 - acc: 0.9733
# 0.2517001299017476
# Epoch 1/1
# 19402/19402 [==============================] - 45s 2ms/step - loss: 0.1051 - acc: 0.9750
# 0.25683324633200477
# Epoch 1/1
# 19402/19402 [==============================] - 39s 2ms/step - loss: 0.1056 - acc: 0.9730
# 0.25658461096612867
# Epoch 1/1
# 19402/19402 [==============================] - 43s 2ms/step - loss: 0.1041 - acc: 0.9729
# 0.2590986571665578
# decay the learning rate
# Epoch 1/1
# 19402/19402 [==============================] - 55s 3ms/step - loss: 0.1122 - acc: 0.9721: 2s - loss: 0.1128 - acc: 0. - ETA: 2s -
# 0.25247661552675277
# Epoch 1/1
# 19402/19402 [==============================] - 42s 2ms/step - loss: 0.1107 - acc: 0.9727
# 0.25350585976734524
# Epoch 1/1
# 19402/19402 [==============================] - 45s 2ms/step - loss: 0.1109 - acc: 0.9717
# 0.25255830047664896
# Epoch 1/1
# 19402/19402 [==============================] - 46s 2ms/step - loss: 0.1082 - acc: 0.9713
# 0.25218060071698084
# Epoch 1/1
# 19402/19402 [==============================] - 47s 2ms/step - loss: 0.1082 - acc: 0.9732
# 0.2559196334352393
# decay the learning rate
# processing time: 2326.3268887996674 seconds

# %%
model = load_model('Keras_cuishou_model')

# %%
# 显示识别错误的数据，并计算准确率
count = 0
sum_loss = 0
for i in range(len(test_data)):
    loss, accuracy = model.evaluate(np.column_stack(test_data[i-1]), np.column_stack(test_pre_label[i-1]), batch_size=1, verbose=0)
    if accuracy == 0:
#         print(test_data[i-1])
        for j in dictionary:
            if (j['id'] == test_data[i-1]).all():
                tmp = j['pre_label'].tolist()
                print(j['sentence'], j['tokenized'], 'label: ', tmp.index(max(tmp)))
#         print('666' for j in dictionary if j['id'] == test_data[i-1])
    else:
        count += 1
    sum_loss += loss
    loss = sum_loss/len(test_data)
accuracy = count/len(test_data)

print('Accuracy: %f' % (accuracy*100))
print('Loss: %f' % (loss))
ThisTime()
# Out:
# 在吃饭呢 ['在', '吃饭', '呢'] label:  1
# 呃我我现在等那卡要手机去维修好我就上那个app啊 ['呃', '我', '我', '现在', '等', '那卡要', '手机', '去', '维修', '好', '我', '上', '那个', 'app', '啊'] label:  0
# 我上月处理啦那个时间的话你们那里不是要输入那个什么交易密码我忘记交易密码啦然后输了五次就 ['我', '上', '月', '处理', '啦', '那个', '时间', '你们', '那里', '不是', '要', '输入', '那个', '什么', '交易', '密码', '我', '忘记', '交易', '密码', '啦', '输', '了', '五次'] label:  1
# 呃最近我那钱还没到账要下个星期一才到账还想开你们打电话来都是那种 ['呃', '最近', '我', '那', '钱', '还', '没到账', '要', '下个星期', '一才', '到账', '还', '想开', '你们', '打电话', '来', '都', '是', '那种'] label:  2
# 我现在手上拿钱不出来了 ['我', '现在', '手上', '拿', '钱', '不', '出来', '了'] label:  2
# 到底是还一百多还是七百多 ['到底', '是', '还', '一百多', '还是', '七百多'] label:  13
# 呃我忘记了怎样处理了吧 ['呃', '我', '忘记', '了', '怎样处理', '了', '吧'] label:  7
# 卡冻结了今天没法存钱了 ['卡', '冻结', '了', '今天', '没法', '存钱', '了'] label:  1
# 帮我这我我我都忘记了这个 ['帮', '我', '这', '我', '我', '我', '都', '忘记', '了', '这个'] label:  1
# 那目前 ['那', '目前'] label:  2
# 万一处理的要处理 ['万一', '处理', '要', '处理'] label:  0
# 语音提示 ['语音', '提示'] label:  8
# 我不记得密码了 ['我', '不记得', '密码', '了'] label:  7
# 往哪里 ['往', '哪里'] label:  7
# 正在筹得多少钱稍等一下吧 ['正在', '筹得', '多少', '钱', '稍等一下', '吧'] label:  13
# 我想重新绑一张卡该怎么操作 ['我', '想', '重新', '绑', '一张', '卡', '该', '怎么', '操作'] label:  5
# 没有问题就这样噢在开车 ['没有问题', '这样', '噢', '在', '开车'] label:  0
# 现在没有钱的多少钱 ['现在', '没有钱', '多少', '钱'] label:  1
# 忘却处理了 ['忘却', '处理', '了'] label:  1
# 我我我就想知道我就想知道你们我还有多少钱没还这么一直在等这个上一直在涨多少你们从来没有人工台说话都是没 ['我', '我', '我', '想知道', '我', '想知道', '你们', '我', '还有', '多少', '钱', '没还', '这么', '在', '等', '这个', '上', '在', '涨', '多少', '你们', '从来', '没有', '人工', '台', '说话', '都', '是', '没'] label:  13
# 最近挺忙的能跟我到十二号出的处理 ['最近', '挺忙', '能', '跟', '我', '到', '十二号', '出', '处理'] label:  2
# 噢我忘记出来我现在有点事情要处理没来执行 ['噢', '我', '忘记', '出来', '我', '现在', '有点', '事情', '要', '处理', '没', '来', '执行'] label:  1
# 噢我忘了然后我两天事情有点多 ['噢', '我', '忘了', '我', '两天', '事情', '有点', '多'] label:  1
# 我不太记得我正在筹建吗接了 ['我', '不', '记得', '我', '正在', '筹建', '吗', '接', '了'] label:  1
# 是存到网银吧 ['是', '存', '到', '网银', '吧'] label:  7
# 我这边需要点时间能不能 ['我', '这边', '需要', '点', '时间', '能不能'] label:  2
# 什么网结束了我昨天给你反馈了你们怎么你们都没有就是说我昨天反馈到各银行的流水我都发快递给你们客服了你们 ['什么', '网', '结束', '了', '我', '昨天', '给', '你', '反馈', '了', '你们', '怎么', '你们', '都', '没有', '就是说', '我', '昨天', '反馈', '到', '各', '银行', '流水', '我', '都', '发快', '递给', '你们', '客服', '了', '你们'] label:  0
# 剩余资金想告诉我还在想办法请专业接的 ['剩余', '资金', '想', '告诉', '我', '还在', '想办法', '请', '专业', '接'] label:  13
# 三天之内受理不了 ['三天', '受理', '不了'] label:  1
# 在凑钱了 ['在', '凑钱', '了'] label:  0
# 噢我今天我现在我因为我现在呃最近有点紧张了我这个保留使用需要的人 ['噢', '我', '今天', '我', '现在', '我', '因为', '我', '现在', '呃', '最近', '有点', '紧张', '了', '我', '这个', '保留', '使用', '需要', '人'] label:  1
# 还你妈逼 ['还', '你妈逼'] label:  2
# 呃可能下午查询 ['呃', '下午', '查询'] label:  1
# 我现在没有我要到十号了我再我再再有代发工资才有钱周转然后到时候我再发麻到五月十号 ['我', '现在', '没有', '我', '要', '到', '十号', '了', '我', '再', '我', '再', '再有', '代发', '工资', '才', '有钱', '周转', '到时候', '我', '再', '发麻', '到', '五月', '十号'] label:  1
# 呃晚一点吗六点六点的时候吗 ['呃', '晚一点', '吗', '六点', '六点', '时候', '吗'] label:  1
# 下周二吧 ['下周二', '吧'] label:  2
# 充完电处理 ['充完', '电', '处理'] label:  0
# 我这边钱没到账的钱到帐之后马上重新加我这块应该处理一下好不好 ['我', '这边', '钱', '没到账', '钱', '到', '帐', '之后', '马上', '重新', '加', '我', '这块', '处理', '一下', '好不好'] label:  0
# 我尽快好吗我自己添有点紧张 ['我', '尽快', '好吗', '我', '自己', '添', '有点', '紧张'] label:  1
# 呃忘了要给处理 ['呃', '忘了', '要', '给', '处理'] label:  1
# 没有忘记 ['没有', '忘记'] label:  0
# 人工台是多少 ['人工', '台', '是', '多少'] label:  5
# 我没有数 ['我', '没有', '数'] label:  1
# 有问题有问题我只能说十天八天了能不能现在办法你我这个月全抄下来 ['有问题', '有问题', '我', '只能', '说', '十天', '八天', '了', '能不能', '现在', '办法', '你', '我', '这个月', '全', '抄下来'] label:  1
# 你们这个贷款我怎样你还了那也不应该的手续费没没为什么没起来不收费 ['你们', '这个', '贷款', '我', '怎样', '你', '还了', '那', '也', '不', '手续费', '没', '没', '为什么', '没', '起来', '不', '收费'] label:  0
# 还款日期是几号 ['还款', '日期', '是', '几号'] label:  12
# 呃通知到了我忘了忘了呢 ['呃', '通知', '到', '了', '我', '忘了', '忘了', '呢'] label:  1
# 呃我证书是然后暂时资金没周转过来没有五个一两天我晚一点我之前都是按时还的吗 ['呃', '我', '证书', '是', '暂时', '资金', '没', '周转', '过来', '没有', '五个', '一两天', '我', '晚一点', '我', '之前', '都', '是', '按时', '还', '吗'] label:  2
# 我不是跟你那个人工说了我今天晚上他有一张到了我就给他打给她处理的吗 ['我', '不是', '跟', '你', '那个', '人工', '说', '了', '我', '今天', '晚上', '他', '有', '一张', '到', '了', '我', '给', '他', '打', '给', '她', '处理', '吗'] label:  0
# 我一放假欠费达到 ['我', '一', '放假', '欠费', '达到'] label:  2
# 呃因为我这边的话就说呃现在我不说不还就说我现在没有钱哦这边的话应该是二十号 ['呃', '因为', '我', '这边', '说', '呃', '现在', '我', '不', '说', '不', '还', '说', '我', '现在', '没有钱', '哦', '这边', '是', '二十号'] label:  1
# 你今天不行 ['你', '今天', '不行'] label:  1
# 噢万一处理然后我一那个优惠处理好吧 ['噢', '万一', '处理', '我', '一', '那个', '优惠', '处理', '好吧'] label:  0
# 呃我今天不太方便一下没钱存我明天肯定存进去 ['呃', '我', '今天', '不太方便', '一下', '没钱', '存', '我', '明天', '肯定', '存进去'] label:  2
# 呃目前还没有 ['呃', '目前', '还没有'] label:  2
# 网络网络 ['网络', '网络'] label:  1
# 没事没事我什么带什么把这个发过来好吧 ['没事', '没事', '我', '什么', '带', '什么', '把', '这个', '发过来', '好吧'] label:  7
# 我过会处理 ['我', '过会', '处理'] label:  1
# 我现在还的话就是应该没有影响吧我昨天忘了 ['我', '现在', '还', '没有', '影响', '吧', '我', '昨天', '忘了'] label:  0
# 我记住了 ['我', '记住', '了'] label:  0
# 我知道了我现在在开车的 ['我', '知道', '了', '我', '现在', '在', '开车'] label:  0
# 还没到位到了给你还上去的两天 ['还没', '到位', '到', '了', '给', '你', '还', '上去', '两天'] label:  1
# 今天会忙不会弄进去 ['今天', '会忙', '不会', '弄', '进去'] label:  2
# 刚刚出去了 ['刚刚', '出去', '了'] label:  1
# 呃不是这个有没有东路对公账户了对吧 ['呃', '不是', '这个', '有没有', '东路', '对公', '账户', '了', '对吧'] label:  9
# 指定要等到吗发了工资以后他发 ['指定', '要', '等到', '吗', '发', '了', '工资', '以后', '他发'] label:  1
# 我滴妈妈上月发工资我就把它充了你好吧 ['我滴', '妈妈', '上', '月', '发工资', '我', '把', '它', '充', '了', '你好', '吧'] label:  0
# 你们可以自动扣款的吧 ['你们', '可以', '自动扣款', '吧'] label:  7
# 我先是因为等到后给我们这里才能发工资 ['我', '先是', '因为', '等到', '后', '给', '我们', '这里', '才能', '发工资'] label:  1
# 我这个暂时行不行因为我的那个钱包钱夹被偷了我要把卡重新作出从新都补过来知道吧 ['我', '这个', '暂时', '行不行', '因为', '我的', '那个', '钱包', '钱', '夹被', '偷', '了', '我', '要', '把', '卡', '重新', '作出', '从', '新', '都', '补', '过来', '知道', '吧'] label:  0
# 唉你好是 ['唉', '你好', '是'] label:  6
# 嗯进的 ['嗯', '进'] label:  0
# 妈忘记处理了我这边再想办法好 ['妈', '忘记处理', '了', '我', '这边', '再', '想办法', '好'] label:  0
# 不好挂机我说什么没钱我来找密码前三九九幺八嗯六点鼠标怎么还啊 ['不好', '挂机', '我', '说', '什么', '没钱', '我', '来', '找', '密码', '前', '三', '九九', '幺', '八', '嗯', '六点', '鼠标', '怎么', '还', '啊'] label:  0
# 最近的话收多少不是很方便 ['最近', '收', '多少', '不是', '方便'] label:  1
# 没有跟我在外面人开始自动给我打我在车上我等会会去存的 ['没有', '跟', '我', '在', '外面', '人', '开始', '自动', '给我', '打', '我', '在', '车上', '我', '等会', '会', '去', '存'] label:  1
# 我就出来了 ['我', '出来', '了'] label:  0
# 我再给我两天时间就可以还到呢我今天今天没钱我明天后天就可以过来了 ['我', '再', '给我', '两天', '时间', '可以', '还', '到', '呢', '我', '今天', '今天', '没钱', '我', '明天', '后天', '可以', '过来', '了'] label:  1
# 噢忘记了忘记了我今晚过了那个九明早还了 ['噢', '忘记', '了', '忘记', '了', '我', '今晚', '过', '了', '那个', '九', '明早', '还了'] label:  2
# 你稍微等一下我看看今晚八点网点 ['你', '等一下', '我', '看看', '今晚', '八点', '网点'] label:  1
# 滚 ['滚'] label:  2
# 在忙晚两分钟再给我打来 ['在忙', '晚', '两分钟', '再', '给我', '打', '来'] label:  1
# 唉女士您好请讲 ['唉', '女士', '您好', '请讲'] label:  3
# 等着 ['等', '着'] label:  1
# 呃我今天等一下稍晚一点我给你衣服了好吧 ['呃', '我', '今天', '等一下', '晚一点', '我', '给', '你', '衣服', '了', '好吧'] label:  0
# 噢我最近我没有发工资我还不上我看没有可不可以哪个不能推迟几天 ['噢', '我', '最近', '我', '没有', '发工资', '我', '还不上', '我', '看', '没有', '可不可以', '哪个', '不能', '推迟', '几天'] label:  2
# 呃您这边是你我的客服是吧 ['呃', '您', '这边', '是', '你', '我的', '客服', '是', '吧'] label:  3
# 呃那个我四号发工资就有钱了今天我昨天也是借钱了没接到钱啊四号九天了十号发工资我马上就还掉 ['呃', '那个', '我', '四号', '发工资', '有钱', '了', '今天', '我', '昨天', '也', '是', '借钱', '了', '没', '接到', '钱', '啊', '四号', '九天', '了', '十号', '发工资', '我', '马上', '还掉'] label:  2
# 呃在哪个地方 ['呃', '在', '哪个', '地方'] label:  7
# 呃应该没没多大问题吧 ['呃', '没', '没多大', '问题', '吧'] label:  0
# 噢不是问题了我现在哪种呀 ['噢', '不是', '问题', '了', '我', '现在', '哪种', '呀'] label:  7
# 你们会自动扣钱的吧 ['你们', '会', '自动扣', '钱', '吧'] label:  7
# 对公可以吧 ['对公', '可以', '吧'] label:  9
# 我没在你那儿借过钱 ['我', '没', '在', '你', '那儿', '借过', '钱'] label:  14
# 你看一下再说好吧 ['你', '看一下', '再说', '好吧'] label:  0
# 能贷就处理好最近有点忙好 ['能贷', '处理', '好', '最近', '有点', '忙', '好'] label:  0
# 呃我现在经济还不允许能不能等到我直接以后 ['呃', '我', '现在', '经济', '还', '不', '允许', '能不能', '等到', '我', '直接', '以后'] label:  1
# 噢我今天可能现在现在没时间 ['噢', '我', '今天', '现在', '现在', '没时间'] label:  1
# 一会我会处理的不会超过今天呢 ['一会', '我', '会', '处理', '不会', '超过', '今天', '呢'] label:  0
# 不是因为我的手机号码到那个手机坏掉了这个手机刚弄的所有的东西我都要重新审一遍所有的银行卡包括银行卡绑定了这个 ['不是', '因为', '我的', '手机号码', '到', '那个', '手机', '坏掉', '了', '这个', '手机', '刚弄', '所有', '东西', '我', '都', '要', '重新', '审', '一遍', '所有', '银行卡', '包括', '银行卡', '绑定', '了', '这个'] label:  1
# 你好是的 ['你好', '是的'] label:  0
# 我的意思说那个我那可以重新办一个办一个那个那个卡来呃转进去吗 ['我的', '意思', '说', '那个', '我', '那', '可以', '重新', '办', '一个', '办', '一个', '那个', '那个', '卡来', '呃', '转', '进去', '吗'] label:  5
# 你们会自动扣款的吧 ['你们', '会', '自动扣款', '吧'] label:  7
# 处理中遇到问题 ['处理', '中', '遇到', '问题'] label:  7
# 呃我这边工资延迟发放了一个五一以后才能发放五一放假以后你等我一下行吗 ['呃', '我', '这边', '工资', '延迟', '发放', '了', '一个', '五一', '以后', '才能', '发放', '五一', '放假', '以后', '你', '等', '我', '一下', '行吗'] label:  1
# 噢还是没钱但我今天在想办法啊 ['噢', '还是', '没钱', '但', '我', '今天', '在', '想办法', '啊'] label:  1
# 我现在的话手机跟我刚才挂失了然后把一笔什么多少重新下载我可能要晚一点然后银行卡已挂失了现在目前可能我返晚一点吗禁用可能半钟之前 ['我', '现在', '手机', '跟', '我', '刚才', '挂失', '了', '把', '一笔', '什么', '多少', '重新', '下载', '我', '要', '晚一点', '银行卡', '已', '挂失', '了', '现在', '目前', '我返', '晚一点', '吗', '禁用', '半钟', '之前'] label:  0
# 过段时间吧现在真的周转不开 ['过段时间', '吧', '现在', '周转', '不', '开'] label:  2
# 我有事情在外地没办法处理那明天回信怎么才可以处理掉 ['我', '有事情', '在', '外地', '没办法', '处理', '那', '明天', '回信', '怎么', '才', '可以', '处理掉'] label:  7
# 是不是出人账号现在我不是想办法吧 ['是不是', '出人', '账号', '现在', '我', '不是', '想办法', '吧'] label:  7
# 要自己冲值吗 ['要', '自己', '冲值', '吗'] label:  7
# 已经扣过钱了就别再打来电话了 ['已经', '扣过', '钱', '了', '别', '再', '打来', '电话', '了'] label:  0
# 我说我我每天把这这么时间 ['我', '说', '我', '我', '每天', '把', '这', '这么', '时间'] label:  2
# 按按多少啊 ['按', '按', '多少', '啊'] label:  8
# 你听我解释我这是有特殊情况不是故意不还的 ['你', '听', '我', '解释', '我', '这是', '有', '特殊情况', '不是故意', '不', '还'] label:  1
# 直接转账么还是等你们来扣 ['直接', '转账', '么', '还是', '等', '你们', '来', '扣'] label:  7
# 行行行行我看一下 ['行行', '行行', '我', '看一下'] label:  0
# 没钱啊基金在我打那个国那个弓弦他他说要明天才结给我 ['没钱', '啊', '基金', '在', '我', '打', '那个', '国', '那个', '弓弦', '他', '他', '说', '要', '明天', '才', '结', '给我'] label:  1
# 你直接哪里打扣 ['你', '直接', '哪里', '打扣'] label:  0
# 呃现在钱没到帐的周六都能还了 ['呃', '现在', '钱', '没到', '帐', '周六', '都', '能', '还了'] label:  2
# 呃我只显示下载不到那个app我现在在上班我下班了再说好吧 ['呃', '我', '只', '显示', '下载', '不到', '那个', 'app', '我', '现在', '在', '上班', '我', '下班', '了', '再说', '好吧'] label:  7
# 呃我的了我的了 ['呃', '我的', '了', '我的', '了'] label:  1
# 我现在手头有点紧 ['我', '现在', '手头', '有点', '紧'] label:  2
# 呃我怎样处理我才受理啊我忘了这个人是太多了 ['呃', '我', '怎样处理', '我', '才', '受理', '啊', '我', '忘了', '这个', '人', '是', '多', '了'] label:  7
# 我最近快点处理 ['我', '最近', '快点', '处理'] label:  0
# 嗯等一下就说我想本子天可不可以 ['嗯', '等一下', '说', '我', '想', '本子', '天', '可不可以'] label:  2
# 唉你好哪位喂你好是的 ['唉', '你好', '哪位', '喂', '你好', '是的'] label:  6
# 不是也不是没没钱也不是化解处理现在我那个银行卡把原来绑定的银行卡冻结了冻结然后我我 ['不是', '也', '不是', '没', '没钱', '也', '不是', '化解', '处理', '现在', '我', '那个', '银行卡', '把', '原来', '绑定', '银行卡', '冻结', '了', '冻结', '我', '我'] label:  7
# 我说我说你们这公司是由北还是干嘛 ['我', '说', '我', '说', '你们', '这', '公司', '是', '由北', '还是', '干嘛'] label:  4
# 晚上五点钟处理你们人工 ['晚上', '五点钟', '处理', '你们', '人工'] label:  0
# 在哪 ['在', '哪'] label:  7
# 要哪里 ['要', '哪里'] label:  7
# 不是明天才到期么 ['不是', '明天', '才', '到期', '么'] label:  12
# 麻烦请讲 ['麻烦', '请讲'] label:  3
# 我查我都不知道 ['我', '查', '我', '都', '不知道'] label:  7
# 可以的我收购了二十号会处理的啊我尽快处理 ['可以', '我', '收购', '了', '二十号', '会', '处理', '啊', '我', '尽快', '处理'] label:  0
# 我我和你说话我就查我不还上有错我等着你们记得记得给我打到我老婆她给我给我们家是多少钱 ['我', '我', '和', '你', '说话', '我', '查', '我', '不', '还上', '有错', '我', '等', '着', '你们', '记得', '记得', '给我', '打到', '我', '老婆', '她', '给我', '给', '我们', '家', '是', '多少', '钱'] label:  0
# 下班 ['下班'] label:  1
# 我正在就要钱怎么弄钱 ['我', '正在', '要钱', '怎么弄', '钱'] label:  0
# 我不记得在哪还 ['我', '不记得', '在哪还'] label:  7
# 呃我问你们你们这个能自己扣吧 ['呃', '我', '问', '你们', '你们', '这个', '能', '自己扣', '吧'] label:  7
# 好的我等会弄 ['好的', '我', '等会', '弄'] label:  0
# 嗯嗯还没处理 ['嗯嗯', '还没处理'] label:  1
# 呃我正在筹钱能再宽限一下喂 ['呃', '我', '正在', '筹钱', '能', '再', '宽限', '一下', '喂'] label:  1
# 一会儿往一点处理网点处理 ['一会儿', '往', '一点', '处理', '网点', '处理'] label:  1
# 目前呃 ['目前', '呃'] label:  2
# 已经没法处理了 ['已经', '没法', '处理', '了'] label:  2
# 早上十点还款每天早上十点还款 ['早上', '十点', '还款', '每天', '早上', '十点', '还款'] label:  2
# 呃你稍等啊我现在就正在处理 ['呃', '你', '稍等', '啊', '我', '现在', '正在', '处理'] label:  1
# 哦好知道了改变我的现在在哪里改 ['哦', '好', '知道', '了', '改变', '我的', '现在', '在', '哪里', '改'] label:  5
# 现在没钱明天还 ['现在', '没钱', '明天', '还'] label:  2
# 喂好的 ['喂', '好的'] label:  0
# 呃忘记了忘记了给我多少 ['呃', '忘记', '了', '忘记', '了', '给我', '多少'] label:  1
# 我说你有没有在听我说话我说为为什么要叫还三千多呢 ['我', '说', '你', '有没有', '在', '听', '我', '说话', '我', '说', '为', '为什么', '要', '叫', '还', '三千多', '呢'] label:  12
# 我昨天那个我有客户他打了打了没打过来然后现在钱还不够我该吃药的吧我经济上得到那种还进去了 ['我', '昨天', '那个', '我', '有', '客户', '他', '打', '了', '打', '了', '没', '打', '过来', '现在', '钱', '还不够', '我该', '吃药', '吧', '我', '经济', '上', '得到', '那种', '还进去', '了'] label:  2
# 呃等一下我原来的五点钟功能呢 ['呃', '等一下', '我', '原来', '五点钟', '功能', '呢'] label:  0
# 晚上有点晚一点 ['晚上', '有点', '晚一点'] label:  0
# 不是他银行转账还没到账到时候到账了没存进去 ['不是', '他', '银行', '转账', '还', '没到账', '到时候', '到账', '了', '没', '存进去'] label:  1
# 还没有 ['还没有'] label:  0
# 啊那个就是稍微晚两天行不行我这两天可能也有点那个查查在网络两三天行不行啊 ['啊', '那个', '晚', '两天', '行不行', '我', '这两天', '也', '有点', '那个', '查查', '在', '网络', '两三天', '行不行', '啊'] label:  1
# 有钱怎么没有扣不了 ['有钱', '怎么', '没有', '扣不了'] label:  0
# 有问题还有多久就说我还有多少期啊 ['有问题', '还有', '多久', '说', '我', '还有', '多少期', '啊'] label:  13
# 有时间我就弄 ['有时间', '我', '弄'] label:  1
# 我没钱我要网上有钱 ['我', '没钱', '我', '要', '网上', '有钱'] label:  0
# 暂时没有办法处理 ['暂时', '没有', '办法', '处理'] label:  1
# 哪个地方呢 ['哪个', '地方', '呢'] label:  7
# 呃我想请问你一下你们可以听我说一下吗因为我的那个卡绑定的那个卡换掉了我的那个卡掉了现在我要重新绑定一张卡然后我把 ['呃', '我', '想', '请问', '你', '一下', '你们', '可以', '听', '我', '说', '一下', '吗', '因为', '我的', '那个', '卡', '绑定', '那个', '卡换', '掉', '了', '我的', '那个', '卡', '掉', '了', '现在', '我', '要', '重新', '绑定', '一张', '卡', '我', '把'] label:  5
# 噢我在等人给我处理 ['噢', '我', '在', '等人', '给我', '处理'] label:  1
# 就是还没下班吗 ['还没', '下班', '吗'] label:  0
# 他本人现在不在下午才能回来了 ['他', '本人', '现在', '不在', '下午', '才能', '回来', '了'] label:  16
# 嗯怎么办呢 ['嗯', '怎么办', '呢'] label:  1
# 你这是干啥的 ['你', '这是', '干啥'] label:  3
# 应该没问题我现在在外面 ['没问题', '我', '现在', '在', '外面'] label:  0
# 赶紧滚蛋吧你 ['赶紧', '滚蛋', '吧', '你'] label:  2
# 不能开通 ['不能', '开通'] label:  7
# 没有那个不是现在啥扣走了两天了吗 ['没有', '那个', '不是', '现在', '啥', '扣', '走', '了', '两天', '了', '吗'] label:  0
# 是这样我在外地账务处理 ['是', '这样', '我', '在', '外地', '账务', '处理'] label:  0
# 呃我现在就是要要要等到明天才能也没钱还没给我说我是你给我的那个钱 ['呃', '我', '现在', '要', '要', '要', '等到', '明天', '才能', '也', '没钱', '还没', '给我', '说', '我', '是', '你', '给我', '那个', '钱'] label:  1
# 哪个银行代扣的 ['哪个', '银行', '代扣'] label:  10
# 我六月份再用不够 ['我', '六月份', '再用', '不够'] label:  2
# 这位女士你好 ['这位', '女士', '你好'] label:  3
# 现在处理不了那个过要三十天之后才能转出 ['现在', '处理不了', '那个', '过要', '三十天', '之后', '才能', '转', '出'] label:  2
# 你办理的 ['你', '办理'] label:  0
# 网银已经点好吗 ['网银', '已经', '点', '好吗'] label:  0
# 我这什么天 ['我', '这', '什么', '天'] label:  2
# 我这张卡不能用了 ['我', '这', '张', '卡', '不能', '用', '了'] label:  7
# 好的两小时内是吧 ['好的', '两小时', '内', '是', '吧'] label:  0
# 大点儿声行不我这里信号不好 ['大点儿', '声行', '不', '我', '这里', '信号不好'] label:  6
# 现在这个原题那我到哪处理 ['现在', '这个', '原题', '那', '我', '到', '哪', '处理'] label:  7
# 没提醒 ['没', '提醒'] label:  15
# 我银行卡里没有呢 ['我', '银行卡', '里', '没有', '呢'] label:  1
# 呃没问题呃就是东我会把这个等一下把那个钱自动的卡里面直接扣款就行了 ['呃', '没问题', '呃', '东', '我', '会', '把', '这个', '等一下', '把', '那个', '钱', '自动', '卡', '里面', '直接', '扣款', '就行了'] label:  1
# 我今天早上登进去了但是我一下子那个还不了 ['我', '今天', '早上', '登', '进去', '了', '但是', '我', '一下子', '那个', '还不了'] label:  1
# 呃资金有点困难我接到了下午或者呗 ['呃', '资金', '有点', '困难', '我', '接到', '了', '下午', '或者', '呗'] label:  1
# 就现在来还还还没什么钱 ['现在', '来', '还', '还', '还', '没什么', '钱'] label:  1
# 唉我那个那个那个那个那个机器那个那个那个还是交易密码搞忘了你们会那个自动去我吗 ['唉', '我', '那个', '那个', '那个', '那个', '那个', '机器', '那个', '那个', '那个', '还是', '交易', '密码', '搞', '忘了', '你们', '会', '那个', '自动', '去', '我', '吗'] label:  7
# 那个微信能还吗我我我刚找你们的工号但是那种三日关注那个你我因w服务好 ['那个', '微信', '能', '还', '吗', '我', '我', '我', '刚', '找', '你们', '工号', '但是', '那种', '三日', '关注', '那个', '你', '我', '因', '服务', '好'] label:  7
# 望技术了吗处理一下啊 ['望', '技术', '了', '吗', '处理', '一下', '啊'] label:  0
# 我这显示已还款 ['我', '这', '显示', '已', '还款'] label:  0
# 搞不了吗我昨天晚上搞 ['搞', '不了', '吗', '我', '昨天晚上', '搞'] label:  0
# 呃忘记了谢谢提醒 ['呃', '忘记', '了', '谢谢', '提醒'] label:  1
# 那个钱存进去了 ['那个', '钱', '存进去', '了'] label:  0
# 噢一万天一百天我弄回两天没没没时间 ['噢', '一万天', '一百天', '我', '弄回', '两天', '没', '没', '没时间'] label:  2
# 噢我现在出现点情况谢谢 ['噢', '我', '现在', '出现', '点', '情况', '谢谢'] label:  1
# 我稍后会处理的现在钱不够 ['我', '稍后', '会', '处理', '现在', '钱', '不够'] label:  1
# 我说你们刚刚不是打电话过来过了嘛我不是跟他那个了说过了吗 ['我', '说', '你们', '刚刚', '不是', '打电话', '过来', '过', '了', '嘛', '我', '不是', '跟', '他', '那个', '了', '说过', '了', '吗'] label:  11
# 下午查询 ['下午', '查询'] label:  1
# 当你处理 ['当', '你', '处理'] label:  0
# 呃忘了忘了申请不了 ['呃', '忘了', '忘了', '申请', '不了'] label:  1
# 资金有点紧张暂时发中北哈谢谢 ['资金', '有点', '紧张', '暂时', '发中', '北哈', '谢谢'] label:  1
# 嗯好的好的我的代码能忙完以后我再再咨询的好吗 ['嗯', '好的', '好的', '我的', '代码', '能', '忙完', '以后', '我', '再', '再', '咨询', '好吗'] label:  1
# 那我这边的话今天不处理 ['那', '我', '这边', '今天', '不处理'] label:  2
# 这是我男朋友借的我也不知道 ['这是', '我', '男朋友', '借', '我', '也', '不知道'] label:  16
# 不是不是我只是忘记处理了 ['不是', '不是', '我', '只是', '忘记处理', '了'] label:  0
# 是没钱然后我打那个四零零那个电话已经说了嘛上海那边的那个电话我已经跟他说我就说我的我要十五号发工资查询以前好 ['是', '没钱', '我', '打', '那个', '四', '零零', '那个', '电话', '已经', '说', '了', '嘛', '上海', '那边', '那个', '电话', '我', '已经', '跟', '他', '说', '我', '说', '我的', '我', '要', '十五号', '发工资', '查询', '以前', '好'] label:  1
# 噢我等到自己处理好又忘记了呃大概几点办理亲情本人打电话 ['噢', '我', '等到', '自己', '处理', '好', '又', '忘记', '了', '呃', '几点', '办理', '亲情', '本人', '打电话'] label:  12
# 我我我都比较忙我现在就是就是个人的事就行 ['我', '我', '我', '都', '比较忙', '我', '现在', '个人', '事', '行'] label:  1
# 觉得自己不可以克的吗 ['觉得', '自己', '不可以', '克', '吗'] label:  0
# 嗯昨天晚上还的时候上面显示是不能手动还款 ['嗯', '昨天晚上', '还', '时候', '上面', '显示', '是', '不能', '手动', '还款'] label:  7
# 我就欠了吗我开展你的头嘛 ['我', '欠', '了', '吗', '我', '开展', '你', '头', '嘛'] label:  0
# 是的暂未处理 ['是的', '暂未处理'] label:  1
# 在忙给我留言 ['在忙', '给我', '留言'] label:  1
# 处理过没成功 ['处理', '过', '没成功'] label:  0
# 然后我我稍后我在atm机上面方法吧 ['我', '我', '稍后', '我', '在', 'atm', '机', '上面', '方法', '吧'] label:  1
# 我的钱在里面多少分泌你改正吗 ['我的', '钱', '在', '里面', '多少', '分泌', '你', '改正', '吗'] label:  0
# 嗯今天是没钱我要晚一点才有网点处理里面已经处理可以吗 ['嗯', '今天', '是', '没钱', '我', '要', '晚一点', '才', '有', '网点', '处理', '里面', '已经', '处理', '可以吗'] label:  0
# 没能力还了 ['没能力', '还了'] label:  1
# 没有我是真没有但是我会尽快想办法我已经联系朋友了 ['没有', '我', '是', '没有', '但是', '我', '会', '尽快', '想办法', '我', '已经', '联系', '朋友', '了'] label:  1
# 我说我未处理呢 ['我', '说', '我', '未处理', '呢'] label:  1
# 我现在不方便说给下班乘坐 ['我', '现在', '不方便', '说', '给', '下班', '乘坐'] label:  0
# 那没有没有没有我找不到那个它上面怎么不显示了我所以说我就没搞我直接直接充到余额里面就行是吧 ['那', '没有', '没有', '没有', '我', '找', '不到', '那个', '它', '上面', '怎么', '不', '显示', '了', '我', '所以', '说', '我', '没', '搞', '我', '直接', '直接', '充', '到', '余额', '里面', '就行', '是', '吧'] label:  7
# 说了过两天再跟球的现在没钱 ['说', '了', '过两天', '再', '跟', '球', '现在', '没钱'] label:  1
# 呃我现在就在那 ['呃', '我', '现在', '在', '那'] label:  0
# 这笔钱我根本没有借过 ['这笔', '钱', '我', '根本', '没有', '借', '过'] label:  14
# 那个扣什么 ['那个', '扣', '什么'] label:  7
# 主要是因为我这个月工资还本来说是这个月二十四号发的然后到现在一直没 ['是', '因为', '我', '这个', '月工资', '还', '本来', '说', '是', '这个月', '二十四', '号发', '到', '现在', '没'] label:  2
# 就是说了三月十四号我就处理这个要处理 ['就是说', '了', '三月', '十四号', '我', '处理', '这个', '要', '处理'] label:  0
# 呃我说我我我想问一下这个时间更改吗因为我这个发工资的日期是十号发工资还没发工资了关键是要我想问一下咱们那个 ['呃', '我', '说', '我', '我', '我', '想', '问一下', '这个', '时间', '更改', '吗', '因为', '我', '这个', '发工资', '日期', '是', '十号', '发工资', '还没', '发工资', '了', '关键', '是', '要', '我', '想', '问一下', '咱们', '那个'] label:  18
# 三三因为我本身就有手机上那个钱的没过不了唉好的我就我一接到这几个月还款 ['三', '三', '因为', '我', '本身', '有', '手机', '上', '那个', '钱', '没过', '不了', '唉', '好的', '我', '我', '一', '接到', '这', '几个', '月', '还款'] label:  0
# 呃我我能不能更改一下银行卡呀 ['呃', '我', '我', '能不能', '更改', '一下', '银行卡', '呀'] label:  5
# 不用了吧 ['不用', '了', '吧'] label:  0
# 我今天早上一个说了确实管不了好吧 ['我', '今天', '早上', '一个', '说', '了', '管不了', '好吧'] label:  1
# 我想更改绑定的银行卡 ['我', '想', '更改', '绑定', '银行卡'] label:  5
# 拨几点开门吗 ['拨', '几点', '开门', '吗'] label:  0
# 喂喂是的 ['喂喂', '是的'] label:  0
# 有问题我就这个时间有条短能不能再长一点 ['有问题', '我', '这个', '时间', '有条', '短', '能不能', '再长', '一点'] label:  1
# 是不是最后一期啊 ['是不是', '最后', '一期', '啊'] label:  12
# 我的卡有些问题因为刚才处理卡吗 ['我的', '卡', '有些', '问题', '因为', '刚才', '处理', '卡', '吗'] label:  1
# 你好那个我想那个恩问一下可以那个延迟还款吗因为我这边的话恐怕暂时抽不上我想就是说呃还 ['你好', '那个', '我', '想', '那个', '恩', '问一下', '可以', '那个', '延迟', '还款', '吗', '因为', '我', '这边', '恐怕', '暂时', '抽不上', '我', '想', '就是说', '呃', '还'] label:  1
# 没什么钱 ['没什么', '钱'] label:  2
# 没钱再给我两天时间好不好我把电充得还给你们还进去啊 ['没钱', '再', '给我', '两天', '时间', '好不好', '我', '把', '电充', '得', '还', '给', '你们', '还进去', '啊'] label:  1
# 我现在身上暂时没钱又要网点吧也应该也就是明天左右应该每天晚上我要不明天晚上要 ['我', '现在', '身上', '暂时', '没钱', '又', '要', '网点', '吧', '也', '也', '明天', '每天晚上', '我', '要', '不', '明天', '晚上', '要'] label:  1
# 钱转进去就行了吧 ['钱', '转', '进去', '就行了', '吧'] label:  7
# 我说怎么找那六百九十三万也不是一百 ['我', '说', '怎么', '找', '那', '六百', '九', '十三万', '也', '不是', '一百'] label:  7
# 自动扣费吗 ['自动扣费', '吗'] label:  7
# 上次我最近两天处理啊 ['上次', '我', '最近', '两天', '处理', '啊'] label:  1
# 现在资金运转主要状况我享受这种天二百二十号不是发工资我的怀里 ['现在', '资金', '运转', '状况', '我', '享受', '这种', '天', '二百', '二十号', '不是', '发工资', '我的', '怀里'] label:  1
# 我要查我处理的也就这样了上班 ['我', '要', '查', '我', '处理', '也', '这样', '了', '上班'] label:  0
# 我这两天除了今天不一定哈 ['我', '这两天', '除了', '今天', '不', '哈'] label:  1
# 是我信用卡号好吗 ['是', '我', '信用卡', '号', '好吗'] label:  7
# 呃问题处理的话有时间就处理好呢 ['呃', '问题', '处理', '有时间', '处理', '好', '呢'] label:  1
# 我没有借过钱啊 ['我', '没有', '借过', '钱', '啊'] label:  14
# 本来今天发工资了不知道等下发我就转进去要不就很久了 ['本来', '今天', '发工资', '了', '不知道', '等', '下发', '我', '转', '进去', '要', '不', '久', '了'] label:  0
# 我在资金还没有到能不能帮我还那个信用卡转账还款 ['我', '在', '资金', '还没有', '到', '能不能', '帮', '我', '还', '那个', '信用卡', '转账', '还款'] label:  7
# 怎么了你好 ['怎么', '了', '你好'] label:  3
# 这几天是没填 ['这几天', '是', '没填'] label:  1
# 什么时候什么时候好了 ['什么', '时候', '什么', '时候', '好', '了'] label:  12
# 忘记了帮我更新处理进去啊 ['忘记', '了', '帮', '我', '更新', '处理', '进去', '啊'] label:  0
# 我现在没钱可以过一阵子么 ['我', '现在', '没钱', '可以', '过', '一阵子', '么'] label:  2
# 你们这自动扣费啊 ['你们', '这', '自动扣费', '啊'] label:  0
# 没有办法处理 ['没有', '办法', '处理'] label:  1
# 我现在还在医院的我回去再说好吧我已经跟你说过一次了我今天的检查 ['我', '现在', '还在', '医院', '我', '回去', '再说', '好吧', '我', '已经', '跟', '你', '说过', '一次', '了', '我', '今天', '检查'] label:  1
# 哦不是现在在外面没没回去大概要要到点钟回去的时候就给了我现在在外面 ['哦', '不是', '现在', '在', '外面', '没', '没', '回去', '要', '要', '到', '点钟', '回去', '时候', '给', '了', '我', '现在', '在', '外面'] label:  0
# 对公转账怎么操作 ['对公', '转账', '怎么', '操作'] label:  9
# 那我今天上网现在插上情况吧 ['那', '我', '今天', '上网', '现在', '插上', '情况', '吧'] label:  1
# 我直接给你们转账给我个账号 ['我', '直接', '给', '你们', '转账', '给我', '个', '账号'] label:  9
# 万一处理发挥处理了 ['万一', '处理', '发挥', '处理', '了'] label:  0
# 呃银关于是我在那个村里面嘛然后我们这个信号不太好后让我拨你连接上就能转可以吧 ['呃', '银', '关于', '是', '我', '在', '那个', '村', '里面', '嘛', '我们', '这个', '信号', '不太好', '后', '让', '我', '拨', '你', '连接', '上', '能', '转', '可以', '吧'] label:  0
# 我是你们那边代扣一下好不好我那个钱已经在卡里去了我那个通过那个app我不知道怎么搞怎么不知道怎么弄的 ['我', '是', '你们', '那边', '代扣', '一下', '好不好', '我', '那个', '钱', '已经', '在', '卡里', '去', '了', '我', '那个', '通过', '那个', 'app', '我', '不知道', '怎么', '搞', '怎么', '不知道', '怎么弄'] label:  0
# 我现在没时间弄这因为不也得两天因为恩我们工资还没发没没打到卡里面去 ['我', '现在', '没时间', '弄', '这', '因为', '不', '也', '得', '两天', '因为', '恩', '我们', '工资', '还没', '发没', '没', '打', '到', '卡', '里面', '去'] label:  2
# 可以自动扣费的吧 ['可以', '自动扣费', '吧'] label:  7
# 能不能别再打来了 ['能不能', '别', '再', '打来', '了'] label:  1
# 我刚才充了一下好像还款失败了 ['我', '刚才', '充了', '一下', '还款', '失败', '了'] label:  7
# 没问题我马上处理不过下次能不能早点提醒我啊 ['没问题', '我', '马上', '处理', '不过', '下次', '能不能', '早点', '提醒', '我', '啊'] label:  15
# 我也没去处理 ['我', '也', '没', '去', '处理'] label:  1
# 噢行行网上怎么能忘记了好吧 ['噢', '行行', '网上', '怎么', '能', '忘记', '了', '好吧'] label:  1
# 找错人了 ['找错人', '了'] label:  16
# 没有我就说我现在在外地取现利息算利息吧 ['没有', '我', '说', '我', '现在', '在', '外地', '取现', '利息', '算', '利息', '吧'] label:  1
# 我等一下冲到银行卡里面它会自己扣啊 ['我', '等一下', '冲', '到', '银行卡', '里面', '它会', '自己扣', '啊'] label:  7
# 就现在吧 ['现在', '吧'] label:  0
# 我没以前 ['我', '没', '以前'] label:  1
# 我最近两天给你吧 ['我', '最近', '两天', '给', '你', '吧'] label:  1
# 我没问题啊是你们的那个地方有问题啊 ['我', '没问题', '啊', '是', '你们', '那个', '地方', '有问题', '啊'] label:  7
# 呃不好意思啊我忘记了还有这么回事我我有一款买这都过几天才能回来然后你能不能稍等 ['呃', '不好意思', '啊', '我', '忘记', '了', '还有', '这么回事', '我', '我', '有', '一款', '买', '这', '都', '过几天', '才能', '回来', '你', '能不能', '稍等'] label:  2
# 我现在没钱我可能要晚几天还进去 ['我', '现在', '没钱', '我', '要', '晚', '几天', '还进去'] label:  2
# 我现在就是说想办法觉得我会及时处理 ['我', '现在', '就是说', '想办法', '觉得', '我', '会', '及时处理'] label:  0
# 人工是多少 ['人工', '是', '多少'] label:  5
# 请现在还没有弄吗 ['请', '现在', '还没有', '弄', '吗'] label:  0
# 现在还还不够今天呃不够疑惑疑惑为什么网络购物 ['现在', '还', '还不够', '今天', '呃', '不够', '疑惑', '疑惑', '为什么', '网络', '购物'] label:  1
# 呃没没钱我刚才你们电话来购汇跟你们说过了你们说记录档案了我说我有钱我一定尽快交不会拖你们的然后刚才电话也跟你说过了 ['呃', '没', '没钱', '我', '刚才', '你们', '电话', '来', '购汇', '跟', '你们', '说过', '了', '你们', '说', '记录', '档案', '了', '我', '说', '我', '有钱', '我', '尽快', '交', '不会', '拖', '你们', '刚才', '电话', '也', '跟', '你', '说过', '了'] label:  1
# 忘记了忘记了怎样处理 ['忘记', '了', '忘记', '了', '怎样处理'] label:  7
# 唉两千几 ['唉', '两千', '几'] label:  13
# 噢我现在在外面然后我在附近有没有银行交易系统 ['噢', '我', '现在', '在', '外面', '我', '在', '附近', '有没有', '银行', '交易系统'] label:  1
# 你好好 ['你好', '好'] label:  0
# 你等会啊我把你跟他说好吗现在不在这边好吧 ['你', '等会', '啊', '我', '把', '你', '跟', '他', '说好', '吗', '现在', '不在', '这边', '好吧'] label:  0
# 呃我忘记处理了然后我今天他正好没有时间我看过晚上扣扣款后就就就还了没问题或者是明天 ['呃', '我', '忘记处理', '了', '我', '今天', '他', '正好', '没有', '时间', '我', '看过', '晚上', '扣', '扣款', '后', '还了', '没问题', '或者', '是', '明天'] label:  1
# 呃忘记的我稍晚一点五一处理 ['呃', '忘记', '我', '晚一点', '五一', '处理'] label:  2
# 滚蛋吧你 ['滚蛋', '吧', '你'] label:  2
# Accuracy: 94.437421
# Loss: 0.239171
# This time is:  2019-06-06 19:43:59

# %%
model.save(date+'_Keras_cuishou_model')

# %%
print(max_len)
# Out:
# 67

# %%
print(pre_stopwords)
# Out:
# ['', '', '', '', '', '', '', '', '', '稍微', '稍', '很', '的', '就是', '这么', '那么', '过去', '过来', '可能', '一直', '比较', '有点']

# %%
model = load_model('Keras_cuishou_model_20190514_96_leakyrelu')

# %%
w2v_model = Word2Vec.load('20190522_w2v_model')
w2v_model2 = Word2Vec.load('20190522_w2v_model_pos_embed')

# %%
sheet4 = readbook.sheet_by_name('predict')
predict_set = []

for i in range(sheet4.nrows-1):
    predict_set.append(sheet4.cell(i+1,0).value)

_, _, predict_id, _ = data_preprocessing(predict_set, BOW)
predict_padded_data,_ = padding_sts(predict_id, max_len)
print(len(predict_padded_data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4b16f6ded063> in <module>
# ----> 1 sheet4 = readbook.sheet_by_name('predict')
#       2 predict_set = []
#       3
#       4 for i in range(sheet4.nrows-1):
#       5     predict_set.append(sheet4.cell(i+1,0).value)
#
# NameError: name 'readbook' is not defined

# %%
w2v_model = Word2Vec.load('20190521_w2v_model')

# %%
print(w2v_model.most_similar(positive=['可能']))
# Out:
# [('估计', 0.7111688852310181), ('倒把', 0.6890275478363037), ('不照', 0.6791861057281494), ('活转', 0.6752203702926636), ('甚至', 0.6734603643417358), ('要明', 0.6718773245811462), ('微软', 0.6554404497146606), ('留款', 0.6554221510887146), ('越过', 0.6531094312667847), ('少扣', 0.6469331979751587)]
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
new_sts = ['没问题','没问题','没问题','没问题','没问题','啦啦','没问题','没问题','没问题','没问题','没问题','没问题','没问题','放心']
tokenized.append(new_sts)
new_sts = [['没问题','没问题','没问题','没问题','没问题','啦啦','没问题','没问题','没问题','没问题','没问题','没问题','没问题','放心']]
w2v_model.build_vocab(new_sts, update=True)
w2v_model.train(tokenized,total_examples=w2v_model.corpus_count,epochs=1)
# Out:
# (110178, 174672)

# %%
jieba.load_userdict("催收文本-newdic.txt")
sts1 = '晚一点点'
sts1_cut = jieba.lcut(sts1)
print(sts1,sts1_cut)
# Out:
# 晚一点点 ['晚一点', '点']

# %%
A = []
C = []
A.append('1')
A.append('2')
A.append('666')
C.append(A)
C.append(A)
print(A, C)
B = []
# B = [x for j in C for x in j]
B += A
B += A
print(B)
# Out:
# ['1', '2', '666'] [['1', '2', '666'], ['1', '2', '666']]
# ['1', '2', '666', '1', '2', '666']
